# %% [markdown]
# <h1>fix way it's saving data </h1>

# %%
import os
import tweepy
import pandas as pd
import json


def grabTweets(api, maxId=None):
    print("MAX_ID:: ", maxId)

    homeTweets = api.home_timeline(since_id=maxId)
    data = []
    for t in homeTweets:
        normal = True
        if "retweeted_status" in t._json.keys():
            retweeted = True
            normal = False
        else:
            retweeted = False
        if "favorited_status" in t._json.keys():
            favorited = True
            normal = False
        else:
            favorited = False
#         dictTemp = {
#             "timestamp": t.created_at,
#             "id": t.id,
#             "user": t.user.name,
#             "retweeted": retweeted,
#             "favorited": t.favorited,
#             "quoted": t.is_quote_status,
#             "normal": normal
#         }
        dictTemp = {
            "user":"user2",
            "normal": "normal",
            "retweeted": "retweeted",
            "quoted": "quoted",
            "favorited": "favorited",
            "id": "id",
            "timestamp": "timestamp"
        }
        data.append(dictTemp)
    data.reverse()
    return (data)


def saveData(data):
    if len(data) is not 0:
        #script_path = os.path.dirname(os.path.abspath(__file__))
        df = pd.DataFrame(data)
        print (df)
        cols = df.columns.tolist()
        df = df[[
            "user", "normal", "retweeted", "quoted", "favorited", "id", "timestamp"
        ]]
        #f #u= script_path + '\my_csv.csv'
        df.to_csv('my_csv.csv', float_format='{:f}'.format, header=False, mode='a')
        print(df.head())
    else:
        print('No new tweets')


def scrapeTwitter(df, api):
    try:
        idStart = df.id.iloc[-1]
    except IndexError:
        idStart = None
    idStart=2
    saveData(grabTweets(api, idStart))


def main():
    #script_path = os.path.dirname(os.path.abspath(__file__))
    keysFile = open(( "keys.txt"), "r")
    keys = keysFile.read().splitlines()
    keysFile.close()
    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]

    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    df = pd.DataFrame(columns=[
            "user", "normal", "retweeted", "quoted", "favorited", "id", "timestamp"
    ])
    f = 'my_csv.csv'
    if not os.path.isfile(f):
        df.to_csv(f, float_format='{:f}'.format, header='column_names')
    else:
        df = pd.read_csv(f)
    scrapeTwitter(df, api)


if __name__ == "__main__":
     main()

df2 = pd.read_csv('my_csv.csv')
df2.tail()
# Out:
# ('MAX_ID:: ', 2)
#     favorited  id  normal  quoted  retweeted  timestamp   user
# 0   favorited  id  normal  quoted  retweeted  timestamp  user2
# 1   favorited  id  normal  quoted  retweeted  timestamp  user2
# 2   favorited  id  normal  quoted  retweeted  timestamp  user2
# 3   favorited  id  normal  quoted  retweeted  timestamp  user2
# 4   favorited  id  normal  quoted  retweeted  timestamp  user2
# 5   favorited  id  normal  quoted  retweeted  timestamp  user2
# 6   favorited  id  normal  quoted  retweeted  timestamp  user2
# 7   favorited  id  normal  quoted  retweeted  timestamp  user2
# 8   favorited  id  normal  quoted  retweeted  timestamp  user2
# 9   favorited  id  normal  quoted  retweeted  timestamp  user2
# 10  favorited  id  normal  quoted  retweeted  timestamp  user2
# 11  favorited  id  normal  quoted  retweeted  timestamp  user2
# 12  favorited  id  normal  quoted  retweeted  timestamp  user2
# 13  favorited  id  normal  quoted  retweeted  timestamp  user2
# 14  favorited  id  normal  quoted  retweeted  timestamp  user2
# 15  favorited  id  normal  quoted  retweeted  timestamp  user2
# 16  favorited  id  normal  quoted  retweeted  timestamp  user2
# 17  favorited  id  normal  quoted  retweeted  timestamp  user2
# 18  favorited  id  normal  quoted  retweeted  timestamp  user2
# 19  favorited  id  normal  quoted  retweeted  timestamp  user2
#     user  normal  retweeted  quoted  favorited  id  timestamp
# 0  user2  normal  retweeted  quoted  favorited  id  timestamp
# 1  user2  normal  retweeted  quoted  favorited  id  timestamp
# 2  user2  normal  retweeted  quoted  favorited  id  timestamp
# 3  user2  normal  retweeted  quoted  favorited  id  timestamp
# 4  user2  normal  retweeted  quoted  favorited  id  timestamp
#       Unnamed: 0   user retweeted  favorited  quoted     normal  id  timestamp
# 1724          15  user2    normal  retweeted  quoted  favorited  id  timestamp
# 1725          16  user2    normal  retweeted  quoted  favorited  id  timestamp
# 1726          17  user2    normal  retweeted  quoted  favorited  id  timestamp
# 1727          18  user2    normal  retweeted  quoted  favorited  id  timestamp
# 1728          19  user2    normal  retweeted  quoted  favorited  id  timestamp

# %%
df2 = pd.read_csv('my_csv.csv')

# %%
# main()

df2 = pd.read_csv('my_csv.csv')

df2
# Out:
#       Unnamed: 0                               user retweeted  favorited  \
# 0              0                        Crunchyroll      True      False
# 1              1                          KVR Audio      True      False
# 2              2                         Funimation      True      False
# 3              3                              sofia      True      False
# 4              4               The Kansas City Star      True      False
# 5              5                       Plugin Deals      True      False
# 6              6                         Bandeauxx.     False       True
# 7              7            Is this a REAPER Blog ?     False       True
# 8              8               The Kansas City Star      True      False
# 9              9                    Kansas City, MO      True      False
# 10            10                         Bandeauxx.     False       True
# 11            11               The Kansas City Star      True      False
# 12            12                     Computer Music     False       True
# 13            13                        Crunchyroll     False       True
# 14            14               The Kansas City Star      True      False
# 15            15                        Crunchyroll      True      False
# 16            16                         Bandeauxx.     False       True
# 17            17                  Calvin and Hobbes      True      False
# 18            18               The Kansas City Star      True      False
# 19            19                         Bandeauxx.     False       True
# 20             0               The Kansas City Star      True      False
# 21             0               The Kansas City Star     False       True
# 22             1                    Kansas City, MO      True      False
# 23             0                           ill-esha      True      False
# 24             1  Premium Organic Blockchain Wyvern      True      False
# 25             2               The Kansas City Star     False       True
# 26             3                         Bandeauxx.     False       True
# 27             4                        Crunchyroll      True      False
# 28             0                              sofia      True      False
# 29             1               The Kansas City Star      True      False
# ...          ...                                ...       ...        ...
# 1659          10                               user    normal  retweeted
# 1660          11                               user    normal  retweeted
# 1661          12                               user    normal  retweeted
# 1662          13                               user    normal  retweeted
# 1663          14                               user    normal  retweeted
# 1664          15                               user    normal  retweeted
# 1665          16                               user    normal  retweeted
# 1666          17                               user    normal  retweeted
# 1667          18                               user    normal  retweeted
# 1668          19                               user    normal  retweeted
# 1671  quoted  favorited                   id            timestamp
# 1672  quoted  favorited                   id            timestamp
# 1673  quoted  favorited                   id            timestamp
# 1674  quoted  favorited                   id            timestamp
# 1675  quoted  favorited                   id            timestamp
# 1676  quoted  favorited                   id            timestamp
# 1677  quoted  favorited                   id            timestamp
# 1678  quoted  favorited                   id            timestamp
# 1679  quoted  favorited                   id            timestamp
# 1680  quoted  favorited                   id            timestamp
# 1681  quoted  favorited                   id            timestamp
# 1682  quoted  favorited                   id            timestamp
# 1683  quoted  favorited                   id            timestamp
# 1684  quoted  favorited                   id            timestamp
# 1685  quoted  favorited                   id            timestamp
# 1686  quoted  favorited                   id            timestamp
# 1687  quoted  favorited                   id            timestamp
# 1688  quoted  favorited                   id            timestamp
#
# [1689 rows x 8 columns]

# %%
df2.drop(columns='Unnamed: 0', inplace=True)

# %%
    keysFile = open("keys.txt", "r")
    keys = keysFile.read().splitlines()

    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]

    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)

# %%
df3 = pd.read_csv('my_csv.csv')
maxId = df3.loc[0,'id']
homeTweets = api.home_timeline(since_id=maxId)
data = []
for t in homeTweets:
    normal = True
    if "retweeted_status" in t._json.keys():
        retweeted = True
        normal = False
    else:
        retweeted = False
    if "favorited_status" in t._json.keys():
        favorited = True
        normal = False
    else:
        favorited = False
    print(maxId < t.id)
    dictTemp = {
        "timestamp": t.created_at,
        "id": t.id,
        "user": t.user.name,
        "retweeted": retweeted,
        "favorited": t.favorited,
        "quoted": t.is_quote_status,
        "normal": normal
    }
    data.append(dictTemp)
    print(dictTemp, maxId)
    print('\n')
# Out:
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 17, 6, 7), 'id': 1011656866252886018, 'user': 'KVR Audio', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 17, 3, 53), 'id': 1011656307214913538, 'user': 'Siraj Raval', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 17, 0, 8), 'id': 1011655361672011776, 'user': 'Crunchyroll', 'retweeted': True, 'favorited': False, 'quoted': False, 'normal': False} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 59, 50), 'id': 1011655287239946242, 'user': 'Crunchyroll', 'retweeted': True, 'favorited': False, 'quoted': False, 'normal': False} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 57, 3), 'id': 1011654587340722185, 'user': 'The Kansas City Star', 'retweeted': True, 'favorited': False, 'quoted': False, 'normal': False} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 56, 2), 'id': 1011654328833146880, 'user': 'The Kansas City Star', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 55, 3), 'id': 1011654083437125632, 'user': 'Anime News Network', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 55, 3), 'id': 1011654082015186944, 'user': 'Anime News Network', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 54, 36), 'id': 1011653969154859008, 'user': 'Kansas City, MO', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 53, 18), 'id': 1011653643634970624, 'user': 'EDM.com', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 52, 35), 'id': 1011653462113701888, 'user': 'Mega Man', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 52, 2), 'id': 1011653323945062400, 'user': 'Plugin Deals', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 52, 2), 'id': 1011653323458596865, 'user': 'The Kansas City Star', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 51, 1), 'id': 1011653068029612032, 'user': 'Plugin Deals', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 50, 6), 'id': 1011652835782660096, 'user': 'Spitfire Audio', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 49, 4), 'id': 1011652575433756672, 'user': 'Calvin and Hobbes', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 49, 1), 'id': 1011652563723325440, 'user': 'EDM.com', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 45, 3), 'id': 1011651567743852544, 'user': 'Anime News Network', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762
#
#
# True
# {'timestamp': datetime.datetime(2018, 6, 26, 16, 45, 3), 'id': 1011651566418481152, 'user': 'Anime News Network', 'retweeted': False, 'favorited': False, 'quoted': False, 'normal': True} 1011640003997429762

# %%
df2.id.iloc[-1]
# Out:
# 1012042794800746497
