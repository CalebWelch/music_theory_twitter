# %% [markdown]
# <h1>fix way it's saving data </h1>

# %%
import os
import tweepy
import pandas as pd
import json


def grabTweets(api, maxId=None):
    print("MAX_ID:: ", maxId)
    homeTweets = api.home_timeline(since_id=maxId)
    data = []
    for t in homeTweets:
        normal = True
        if "retweeted_status" in t._json.keys():
            retweeted = True
            normal = False
        else:
            retweeted = False
        if "favorited_status" in t._json.keys():
            favorited = True
            normal = False
        else:
            favorited = False
        dictTemp = {
            "timestamp": t.created_at,
            "id": t.id,
            "user": t.user.name.encode('utf-8'),
            "retweeted": retweeted,
            "favorited": t.favorited,
            "quoted": t.is_quote_status,
            "normal": normal
        }
        data.append(dictTemp)
    data.reverse()
    return (data)


def saveData(data):
    if len(data) is not 0:
        #script_path = os.path.dirname(os.path.abspath(__file__))
        df = pd.DataFrame(data)
        print (df)
        cols = df.columns.tolist()
        df = df[[
                 "user", "normal", "retweeted", "quoted", "favorited", "id", "timestamp"
        ]]
        #f #u= script_path + '\my_csv.csv'
        df.to_csv('my_csv.csv', float_format='{:f}'.format, header=False, mode='a')
        print(df.head())
    else:
        print('No new tweets')


def scrapeTwitter(df, api):
    try:
        idStart = df.id.iloc[-1]
    except IndexError:
        idStart = None
    saveData(grabTweets(api, idStart))


def main():
    #script_path = os.path.dirname(os.path.abspath(__file__))
    keysFile = open(( "keys.txt"), "r")
    keys = keysFile.read().splitlines()
    keysFile.close()
    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]

    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    df = pd.DataFrame(columns=[
            "user", "normal", "retweeted", "quoted", "favorited", "id", "timestamp"
    ])
    f = 'my_csv.csv'
    if not os.path.isfile(f):
        df.to_csv(f, float_format='{:f}'.format, header='column_names')
    else:
        df = pd.read_csv(f)
    scrapeTwitter(df, api)


if __name__ == "__main__":
     main()
# Out:
# ('MAX_ID:: ', None)
#     favorited                   id  normal  quoted  retweeted  \
# 0       False  1037783758181679106    True   False      False
# 1       False  1037784754274426881    True   False      False
# 2       False  1037785260141019136    True   False      False
# 3       False  1037786363255508995   False   False       True
# 4       False  1037786523129798658    True   False      False
# 5       False  1037787530295435265    True   False      False
# 6       False  1037787540324003846    True   False      False
# 7       False  1037787851595894785    True    True      False
# 8       False  1037788792785199105    True   False      False
# 9       False  1037789540822466560    True   False      False
# 10      False  1037790546918629378    True   False      False
# 11      False  1037791050427977728    True   False      False
# 12      False  1037792658645770240    True   False      False
# 13      False  1037792689423568896   False    True       True
# 14      False  1037792706636984320    True   False      False
# 15      False  1037792811192672256    True   False      False
# 16      False  1037792816884330502    True   False      False
# 17      False  1037793064482422785    True   False      False
# 18      False  1037795276734394368    True   False      False
# 19      False  1037795473669726210    True   False      False
#
#              timestamp                                   user
# 0  2018-09-06 19:25:03                     Anime News Network
# 1  2018-09-06 19:29:01                      Calvin and Hobbes
# 2  2018-09-06 19:31:01  Crunchyroll @ I miss Crunchyroll Expo
# 3  2018-09-06 19:35:24                           Plugin Deals
# 4  2018-09-06 19:36:02                   The Kansas City Star
# 25                  2018-09-05 13:23:12
# 26                  2018-09-05 13:28:02
# 27                  2018-09-05 13:28:03
# 28                  2018-09-05 13:28:05
# 29                  2018-09-05 13:28:37
# 30                  2018-09-05 13:30:02
# 31                  2018-09-05 13:31:03
# 32                  2018-09-05 13:31:40
# 33                  2018-09-05 13:33:06
# 34                  2018-09-05 13:36:03
# 35                  2018-09-05 13:48:17
# 36                  2018-09-05 14:00:05
# 37                  2018-09-05 14:00:33
# 38                  2018-09-05 14:03:30
# 39                  2018-09-05 14:12:02
# 40                  2018-09-05 14:14:02
# 41                  2018-09-05 14:14:27
# 42                  2018-09-05 14:15:03
# 43                  2018-09-05 14:17:03
# 44                  2018-09-05 14:24:02

# %% [raw]
# df2.drop(columns='Unnamed: 0', inplace=True)

# %%
    keysFile = open("keys.txt", "r")
    keys = keysFile.read().splitlines()

    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]

    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)

# %%
df3 = pd.read_csv('my_csv.csv')
maxId = df3.loc[0,'id']
homeTweets = api.home_timeline(since_id=maxId)
data = []
for t in homeTweets:
    normal = True
    if "retweeted_status" in t._json.keys():
        retweeted = True
        normal = False
    else:
        retweeted = False
    if "favorited_status" in t._json.keys():
        favorited = True
        normal = False
    else:
        favorited = False
    print(maxId < t.id)
    dictTemp = {
        "timestamp": t.created_at,
        "id": t.id,
        "user": t.user.name,
        "retweeted": retweeted,
        "favorited": t.favorited,
        "quoted": t.is_quote_status,
        "normal": normal
    }
    print t.user.name.encode('utf-8')
    data.append(dictTemp)
    print(dictTemp['user'])
# Out:
# False
# The Kansas City Star
# The Kansas City Star
# False
# Anime News Network
# Anime News Network
# False
# Anime News Network
# Anime News Network
# False
# Bandeauxx.
# Bandeauxx.
# False
# The Kansas City Star
# The Kansas City Star
# False
# The Kansas City Star
# The Kansas City Star
# False
# [adult swim]
# [adult swim]
# False
# KCMO Public Library
# KCMO Public Library
# False
# [adult swim]
# [adult swim]
# False
# The Kansas City Star
# The Kansas City Star
# False
# Plugin Deals
# Plugin Deals
# False
# KVR Audio
# KVR Audio
# False
# Whataburger®
# Whataburger®
# False
# Whataburger®
# Whataburger®
# False
# The Kansas City Star
# The Kansas City Star
# False
# Black Rooster Audio
# Black Rooster Audio
# False
# Black Rooster Audio
# Black Rooster Audio
# False
# The Kansas City Star
# The Kansas City Star
# False
# The Kansas City Star
# The Kansas City Star
# False
# Downtown KC 🚸 🚲 🛴 🚊 🚌 Advocate
# Downtown KC 🚸 🚲 🛴 🚊 🚌 Advocate

# %%
a = dictTemp['user']

# %%
a = ("Downtown KC 🚸 🚲 🛴 🚊 🚌 Advocate ")
a = a.decode('utf-8')
a
# Out:
# u'Downtown KC \U0001f6b8 \U0001f6b2 \U0001f6f4 \U0001f68a \U0001f68c Advocate '

# %%
a = unicode(a,"utf-8")

# %%
print a
# Out:
# Downtown KC 🚸 🚲 🛴 🚊 🚌 Advocate

# %%
print(b)
# Out:
# Downtown KC ���� ���� ���� ���� ���� Advocate
